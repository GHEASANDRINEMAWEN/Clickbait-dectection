# %% [markdown]
# # Clickbait Detection with Transformer Models
#
# In this assignment, you will build and evaluate transformer-based models for detecting clickbait headlines. Clickbait refers to content with misleading or sensationalized headlines designed primarily to attract attention and encourage visitors to click on a link, often at the expense of accuracy or quality. Detecting clickbait automatically is an important NLP task with applications in content moderation and media literacy.

# %%
# note that in handin.py this step would need to be removed
# !pip install transformers datasets wandb
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.19.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.14)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.10.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.24.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
# This code block has just standard setup code for running in Python

# Import PyTorch
import torch
from torch import nn
from torch.utils.data import DataLoader, random_split
import numpy as np
import matplotlib.pyplot as plt
import os
import json
import random
from transformers import AutoTokenizer, AutoModel
from datasets import load_dataset

# For experiment tracking
import wandb

# Fix the random seed for reproducability
torch.random.manual_seed(8942764)
torch.cuda.manual_seed(8942764)
np.random.seed(8942764)

# %%
# Please set your device by uncommenting the right version below

# On colab or on a machine with access to an Nvidia GPU  use the following setting
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# if you have an Apple Silicon machine with a GPU, use the following setting
# this should about 3-4 times faster that running it on a plain CPU
# device = 'mps' if torch.backends.mps.is_available() else 'cpu'

# If you will use a cpu, this is the setting
# device='cpu'

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Utility Functions
# These functions help with model setup, data processing, training, and evaluation.
#
# You'll need to implement the parts marked with TODO comments.

# %%
# Function to load the dataset
def load_data():
    """
    Load the clickbait dataset from Hugging Face

    Returns:
        dataset: A dataset dictionary containing train, validation, and test splits
    """
    # TODO: Implement this function to load the dataset from Hugging Face
    # Use the load_dataset function to load the clickbait dataset
    # The dataset ID is "christinacdl/clickbait_notclickbait_dataset"
    clickbait_dataset = load_dataset("christinacdl/clickbait_notclickbait_dataset")
    return clickbait_dataset

# %%
# Function to initialize and return instance of Autotokenizer with the given model name
def get_tokenizer(model_name):
    """
    Get the appropriate tokenizer for the given model name

    Args:
        model_name: Name of the pre-trained model (e.g., 'bert-base-uncased')

    Returns:
        tokenizer: The tokenizer for the specified model
    """
    # TODO: Implement this function
    # Load and return the pre-trained Autotokenizer for the specified model name
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    return tokenizer

# %%
# Tokenization function for data processing
def tokenize(batch, tokenizer):
    """
    Transform text data to tokenized format for model input

    Args:
        batch: Batch of examples from the dataset
        tokenizer: Tokenizer to use for encoding

    Returns:
        Dict with tokenized inputs and labels
    """
    sentences = [x['text'] for x in batch]
    labels = torch.LongTensor([x['label'] for x in batch])
    new_batch = dict(tokenizer(sentences, padding=True, truncation=True, return_tensors="pt"))
    new_batch['label'] = labels
    return new_batch

# %%
# Function to initialize wandb for experiment tracking
def init_wandb(config, project_name):
    """Initialize wandb with given config"""
    wandb.init(
        project=project_name,
        config=config
    )
    return wandb.config

# %%
# Training function
def train(model,
          train_dataset,
          val_dataset,
          num_epochs,
          batch_size,
          optimizer_cls,
          lr,
          weight_decay,
          device,
          tokenizer,
          use_wandb=False):
    """
    Train the model and track with wandb if specified

    Args:
        model: Model to train
        train_dataset: Training dataset
        val_dataset: Validation dataset
        num_epochs: Number of epochs to train for
        batch_size: Batch size for training
        optimizer_cls: Name of optimizer to use ('SGD', 'Adam', 'AdamW')
        lr: Learning rate
        weight_decay: Weight decay for regularization
        device: Device to train on
        tokenizer: Tokenizer for processing inputs
        use_wandb: Whether to log metrics to wandb

    Returns:
        Tuple of (trained model, training history)
    """
    # TODO: Set the model to training mode and move it to the specified device
    model.train()
    model.to(device)

    dataloader = DataLoader(train_dataset, batch_size, shuffle=True,
                          collate_fn=lambda batch: tokenize(batch, tokenizer))

    # TODO: Initialize the optimizers based on the optimizer_cls parameter, with the specified learning rates and weight decays.
    if optimizer_cls == 'SGD':
        optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)
    elif optimizer_cls == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    elif optimizer_cls == 'AdamW':
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    train_loss_history = []
    train_acc_history = []
    val_loss_history = []
    val_acc_history = []

    lossfn = nn.CrossEntropyLoss()  # Using CrossEntropyLoss which expects logits

    global_step = 0

    for e in range(num_epochs):
        epoch_loss_history = []
        epoch_acc_history = []

        # Training loop
        model.train()
        for i, batch in enumerate(dataloader):
            batch = {k:v.to(device) for k,v in batch.items() if isinstance(v, torch.Tensor)}
            y = batch.pop('label')

            # TODO: Implement forward pass and loss computation
            # 1. Pass the batch through the model to get logits
            logits = model(**batch)

            # 2. Calculate the loss using lossfn
            loss = lossfn(logits, y)

            # 3. Calculate the accuracy (percentage of correct predictions)
            predictions = torch.argmax(logits, dim=1)
            accuracy = (predictions == y).float().mean().item()

            # 4. Append each epoch's loss and accuracy to epoch_loss_history and epoch_acc_history
            epoch_loss_history.append(loss.item())
            epoch_acc_history.append(accuracy)

            global_step += 1

            # Print every 100 steps
            if global_step % 100 == 0:
                print(f'Epoch: {e+1}, Step: {global_step}, Train Loss: {epoch_loss_history[-1]:.3e}, Train Accuracy: {epoch_acc_history[-1]:.3f}')

                # Log batch metrics to WandB
                if use_wandb:
                    wandb.log({
                        "global_step": global_step,  # Correct step tracking
                        "train_loss_step": epoch_loss_history[-1],  # Current batch loss
                        "train_accuracy_step": epoch_acc_history[-1],  # Current batch accuracy
                        "epoch": e + 1,
                    })

            # TODO: Implement backward pass and optimization step
            # 1. Zero the gradients
            optimizer.zero_grad()

            # 2. Backpropagate the loss
            loss.backward()

            # 3. Update the model parameters using the optimizer
            optimizer.step()

        # Evaluation on validation set
        # TODO: Set the model to Evaluation mode
        model.eval()
        val_loss, val_acc, _, _, _ = evaluate(model, val_dataset, batch_size, device, tokenizer)

        train_loss_history.append(np.mean(epoch_loss_history))
        train_acc_history.append(np.mean(epoch_acc_history))
        val_loss_history.append(val_loss)
        val_acc_history.append(val_acc)

        print(f'epoch: {e + 1}\t train_loss: {train_loss_history[-1]:.3e}\t train_accuracy:{train_acc_history[-1]:.3f}\t val_loss: {val_loss_history[-1]:.3e}\t val_accuracy:{val_acc_history[-1]:.3f}')

        # Log metrics to wandb if enabled
        if use_wandb:
            wandb.log({
                "epoch": e + 1,
                "train_loss": train_loss_history[-1],
                "train_accuracy": train_acc_history[-1],
                "val_loss": val_loss_history[-1],
                "val_accuracy": val_acc_history[-1]
            })

    return model, (train_loss_history, train_acc_history, val_loss_history, val_acc_history)

# %%
# Evaluation function
@torch.no_grad()
def evaluate(model, dataset, batch_size, device, tokenizer):
    """
    Evaluate model on dataset

    Args:
        model: Model to evaluate
        dataset: Dataset to evaluate on
        batch_size: Batch size for evaluation
        device: Device to run evaluation on
        tokenizer: Tokenizer for processing inputs

    Returns:
        Tuple of (loss, accuracy, predictions, labels, logits)
    """
    # TODO: Set the model to evaluation mode and move it to the specified device
    model.eval()
    model.to(device)

    dataloader = DataLoader(dataset, batch_size, shuffle=False,
                           collate_fn=lambda batch: tokenize(batch, tokenizer))
    lossfn = nn.CrossEntropyLoss()  # Using CrossEntropyLoss which expects logits

    loss_history = []
    acc_history = []
    all_preds = []
    all_labels = []
    all_logits = []

    for i, batch in enumerate(dataloader):
        batch = {k:v.to(device) for k,v in batch.items() if isinstance(v, torch.Tensor)}
        y = batch.pop('label')

        # TODO: Implement the evaluation loop
        # Loop through batches in the dataloader
        # 1. Get model predictions by passing in the batch (logits)
        logits = model(**batch)

        # 2. Calculate loss
        loss = lossfn(logits, y)

        # 3. Get the predictions from the logits in the variable pred
        pred = torch.argmax(logits, dim=1)

        acc = (pred == y).float().mean()

        all_preds.extend(pred.cpu().numpy())
        all_labels.extend(y.cpu().numpy())
        all_logits.extend(logits.cpu().numpy())

        loss_history.append(loss.item())
        acc_history.append(acc.item())

    # TODO: Calculate and return the evaluation metrics
    # Return the mean loss, mean accuracy, all predictions, all labels, and all logits
    return np.mean(loss_history), np.mean(acc_history), all_preds, all_labels, all_logits

# %%
# Function to load a test set and generate predictions
def predict_on_test_set(model, tokenizer, test_file_path, output_file_path, device):
    """
    Generate predictions on a test set and save to file

    Args:
        model: Trained model
        tokenizer: Tokenizer for the model
        test_file_path: Path to the test data file
        output_file_path: Path to save predictions
        device: Device to run inference on
    """
    # Load test data
    with open(test_file_path, 'r') as f:
        test_data = json.load(f)

    print(f"Loaded {len(test_data)} examples from {test_file_path}")

    # Make predictions
    # TODO: Set the model to evaluation mode
    model.eval()

    # TODO: Initialize an empty list to store predictions
    predictions = []

    for item in test_data:
        # TODO: Tokenize the text and move to the correct device as variable inputs
        inputs = tokenizer(item['text'], padding=True, truncation=True, return_tensors="pt")
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # Get predictions
        # TODO: Disable gradient propagation
        with torch.no_grad():
            # TODO: Pass the inputs to the model to get logits
            logits = model(**inputs)
            # TODO: Get the prediction from logits
            pred = torch.argmax(logits, dim=1).item()

        # Store prediction as a string (0 or 1)
        predictions.append(str(pred))

    # Write predictions to file - one prediction per line
    with open(output_file_path, 'w') as f:
        f.write('\n'.join(predictions))

    print(f"Predictions saved to {output_file_path}")

# %% [markdown]
# ## Model Architecture
# This section defines the model architecture for transformer-based text classification.

# %%
# Base Transformer Model class for text classification
class TransformerForTextClassification(nn.Module):
    def __init__(self, model_name, num_classes, freeze_base=False, hidden_size=128, num_layers=1):
        """
        Transformer model with a classification head

        Args:
            model_name: Name of the base transformer model (e.g., 'bert-base-uncased')
            num_classes: Number of output classes
            freeze_base: Whether to freeze the base model parameters
            hidden_size: Size of the hidden layers in the classifier
            num_layers: Number of hidden layers in the classifier
        """
        super().__init__()

        self.base_model = AutoModel.from_pretrained(model_name)

        # Freeze base model if specified
        self.base_model.requires_grad_(not freeze_base)

        if not freeze_base:
            self.unfreeze_top_k_layers(5)

        # Get the hidden size from the base model config
        base_hidden_size = self.base_model.config.hidden_size

        # Build classifier with variable number of hidden layers
        if num_layers == 1:
            self.classifier = nn.Sequential(
                nn.Linear(base_hidden_size, hidden_size),
                nn.ReLU(),
                nn.Linear(hidden_size, num_classes)
            )
        elif num_layers == 2:
            self.classifier = nn.Sequential(
                nn.Linear(base_hidden_size, hidden_size),
                nn.ReLU(),
                nn.Linear(hidden_size, hidden_size),
                nn.ReLU(),
                nn.Linear(hidden_size, num_classes)
            )
        elif num_layers == 3:
            self.classifier = nn.Sequential(
                nn.Linear(base_hidden_size, hidden_size),
                nn.ReLU(),
                nn.Linear(hidden_size, hidden_size),
                nn.ReLU(),
                nn.Linear(hidden_size, hidden_size),
                nn.ReLU(),
                nn.Linear(hidden_size, num_classes)
            )
        else:
            raise ValueError(f"Unsupported number of layers: {num_layers}")

    def unfreeze_top_k_layers(self, k=5):
        """
        Unfreezes the top k layers of a Transformer model (BERT or ModernBERT).

        Parameters:
            model: The Transformer model (e.g., BERT or ModernBERT).
            k: Number of top layers to unfreeze (default is 5).
        """
        # First, freeze all layers in the base model
        for param in self.base_model.parameters():
            param.requires_grad = False

        # Detect whether the model uses standard BERT or ModernBERT
        if hasattr(self.base_model, "encoder"):  # Standard BERT
            layers = self.base_model.encoder.layer
        elif hasattr(self.base_model, "layers"):  # ModernBERT
            layers = self.base_model.layers
        else:
            raise ValueError("Unrecognized model architecture: Cannot find encoder layers.")

        # Get the total number of layers
        total_layers = len(layers)

        # Unfreeze the last k layers
        for i in range(total_layers - k, total_layers):
            for param in layers[i].parameters():
                param.requires_grad = True

        print(f"Unfroze the last {k} layers out of {total_layers} total layers.")

    def forward(self, **base_model_kwargs):
        """Forward pass through the model"""
        outputs = self.base_model(**base_model_kwargs)
        # Use the pooled output for classification
        pooled_output = outputs.last_hidden_state[:, 0, :]  # Extract the [CLS] token embedding
        # Return logits (not probabilities)
        logits = self.classifier(pooled_output)
        return logits

# %%
# Function to create model with specified architecture
def get_model(model_name, num_classes, freeze_base=False, hidden_size=128, num_layers=1):
    """Create model with specified architecture"""
    return TransformerForTextClassification(
        model_name=model_name,
        num_classes=num_classes,
        freeze_base=freeze_base,
        hidden_size=hidden_size,
        num_layers=num_layers
    )

# %% [markdown]
# ### Dataset
# We'll be using a dataset of headlines labeled as either clickbait (1) or not clickbait (0). The dataset comes from Hugging Face and includes training, validation, and test splits. You'll have an opportunity to explore the data distribution and characteristics before building your models.

# %%
# Load dataset
dataset = load_data()
print(dataset)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/437 [00:00<?, ?B/s]
# train.json:   0%|          | 0.00/3.70M [00:00<?, ?B/s]
# val.json:   0%|          | 0.00/184k [00:00<?, ?B/s]
# test.json:   0%|          | 0.00/742k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/43802 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2191 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/8760 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'text'],
#         num_rows: 43802
#     })
#     validation: Dataset({
#         features: ['label', 'text'],
#         num_rows: 2191
#     })
#     test: Dataset({
#         features: ['label', 'text'],
#         num_rows: 8760
#     })
# })

# %%
# Look at some examples
print("\nExamples from training set:")
for i in range(3):
    print(f"Example {i}: {dataset['train'][i]}")

print("\nExamples from validation set:")
for i in range(3):
    print(f"Example {i}: {dataset['validation'][i]}")
# Out:
# Examples from training set:
# Example 0: {'label': 0, 'text': 'Alphabet Scraps Plan to Blanket Globe With Internet Balloons'}
# Example 1: {'label': 0, 'text': 'US Boy Scouts and hikers airlifted from wildfire in Utah'}
# Example 2: {'label': 1, 'text': "Here's What Happened When I Road Tripped Around Southern California For A Week"}
#
# Examples from validation set:
# Example 0: {'label': 1, 'text': '27 Happy Gifts For People Who Love Jamaica'}
# Example 1: {'label': 1, 'text': 'How Adulthood Happens '}
# Example 2: {'label': 0, 'text': 'President Donald Trump Has Historically Low Approval Ratings As He Nears 100-Day Mark'}

# %%
# Look at class distribution
train_labels = [example['label'] for example in dataset['train']]
val_labels = [example['label'] for example in dataset['validation']]
test_labels = [example['label'] for example in dataset['test']]

print("\nClass distribution:")
print(f"Training set: Clickbait: {train_labels.count(1)}, Not clickbait: {train_labels.count(0)}")
print(f"Validation set: Clickbait: {val_labels.count(1)}, Not clickbait: {val_labels.count(0)}")
print(f"Test set: Clickbait: {test_labels.count(1)}, Not clickbait: {test_labels.count(0)}")
# Out:
# Class distribution:
# Training set: Clickbait: 16257, Not clickbait: 27545
# Validation set: Clickbait: 813, Not clickbait: 1378
# Test set: Clickbait: 3252, Not clickbait: 5508

# %% [markdown]
# ## Explore tokenization

# %%
# Explore tokenization
bert_tokenizer = get_tokenizer("bert-base-uncased")
modernbert_tokenizer = get_tokenizer("answerdotai/ModernBERT-base")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/20.8k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.13M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/694 [00:00<?, ?B/s]

# %%
print("\nTokenization examples:")
example_text = dataset['train'][8]['text']
print(f"Original text: '{example_text}'")
print(f"BERT tokenization: {bert_tokenizer.tokenize(example_text)}")
print(f"ModernBERT tokenization: {modernbert_tokenizer.tokenize(example_text)}")
# Out:
# Tokenization examples:
# Original text: '15 Things You Never Noticed About Owning A Cat'
# BERT tokenization: ['15', 'things', 'you', 'never', 'noticed', 'about', 'owning', 'a', 'cat']
# ModernBERT tokenization: ['15', 'ĠThings', 'ĠYou', 'ĠNever', 'ĠNot', 'iced', 'ĠAbout', 'ĠOw', 'ning', 'ĠA', 'ĠCat']

# %% [markdown]
# ## Task 1: Model Selection
#
# In this task, you will compare the performance of two different transformer architectures for the clickbait detection task:
#
# 1. **BERT (bert-base-uncased)**: A widely-used transformer model developed by Google that has been pre-trained on a large corpus of English text.
#
# 2. **ModernBERT (answerdotai/ModernBERT-base)**: A more recent transformer variant that has been trained on newer text data and may have better performance on contemporary language patterns.
#
# You'll train and evaluate both models with the same baseline configuration to determine which architecture provides a stronger foundation for our clickbait detection system.
#
# This comparison will help us understand:
# - Which model better captures the linguistic patterns characteristic of clickbait
# - Whether the newer ModernBERT has advantages over the classic BERT architecture for this specific application
#
# After completing this task, you'll select the better-performing model to use as the foundation for further refinement in Task 2.

# %%
def run_model_selection():
    """Run model selection task comparing BERT and ModernBERT"""

    # Define models to compare
    model_configs = [
        {
            "name": "bert-base-uncased",
            "display_name": "BERT",
            "freeze_base": True
        },
        {
            "name": "answerdotai/ModernBERT-base",
            "display_name": "ModernBERT",
            "freeze_base": True
        }
    ]

    # Training parameters
    train_params = {
        "num_epochs": 3,
        "batch_size": 32,
        "optimizer_cls": "Adam",
        "lr": 1e-3,
        "weight_decay": 1e-4,
        "hidden_size": 128,
        "num_layers": 1
    }

    results = []

    for config in model_configs:
        model_name = config["name"]
        display_name = config["display_name"]
        print(f"\n{'='*50}")
        print(f"Training and evaluating {display_name} model")
        print(f"{'='*50}")

        # Initialize the tokenizer for the selected model
        tokenizer = get_tokenizer(model_name)

        # Initialize wandb
        wandb_config = {**config, **train_params}
        init_wandb(wandb_config, "clickbait-detection-task1")

        # Create model
        model = get_model(
            model_name=model_name,
            num_classes=2,
            freeze_base=config["freeze_base"],
            hidden_size=train_params["hidden_size"],
            num_layers=train_params["num_layers"]
        )

        # Print the number of trainable parameters in the model
        num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        print(f"Model trainable parameters: {num_params}")

        # Train model
        model, logs = train(
            model=model,
            train_dataset=dataset['train'],
            val_dataset=dataset['validation'],
            num_epochs=train_params["num_epochs"],
            batch_size=train_params["batch_size"],
            optimizer_cls=train_params["optimizer_cls"],
            lr=train_params["lr"],
            weight_decay=train_params["weight_decay"],
            device=device,
            tokenizer=tokenizer,
            use_wandb=True
        )

        # Evaluate on validation set
        val_loss, val_acc, _, _, _ = evaluate(
            model=model,
            dataset=dataset['validation'],
            batch_size=train_params["batch_size"],
            device=device,
            tokenizer=tokenizer
        )

        # Record results
        results.append({
            "model_name": model_name,
            "display_name": display_name,
            "val_accuracy": val_acc,
            "val_loss": val_loss,
            "logs": logs,
            "model": model,
            "tokenizer": tokenizer
        })

        wandb.finish()

    # Compare results
    print("\nModel Selection Results:")
    print(f"{'Model':<10} {'Validation Accuracy':<20} {'Validation Loss':<15}")
    print("-" * 45)

    for result in results:
        print(f"{result['display_name']:<10} {result['val_accuracy']:.4f}{' '*15} {result['val_loss']:.4f}")

    return results

# %%
# Run model selection
task1_results = run_model_selection()
# Out:
# ==================================================
# Training and evaluating BERT model
# ==================================================
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: gmawen (gmawen-carnegie-mellon-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_204248-tyfc735p</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/tyfc735p' target="_blank">flowing-puddle-24</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/tyfc735p' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/tyfc735p</a>
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Model trainable parameters: 98690
# Epoch: 1, Step: 100, Train Loss: 3.538e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 200, Train Loss: 2.389e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 300, Train Loss: 2.750e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 400, Train Loss: 1.916e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 500, Train Loss: 1.992e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 600, Train Loss: 3.457e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 700, Train Loss: 3.239e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 800, Train Loss: 1.829e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 900, Train Loss: 3.100e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1000, Train Loss: 2.143e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 1100, Train Loss: 2.096e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 1200, Train Loss: 2.914e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 1300, Train Loss: 3.348e-01, Train Accuracy: 0.844
# epoch: 1	 train_loss: 2.907e-01	 train_accuracy:0.884	 val_loss: 2.819e-01	 val_accuracy:0.895
# Epoch: 2, Step: 1400, Train Loss: 2.813e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 1500, Train Loss: 3.378e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 1600, Train Loss: 2.406e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 1700, Train Loss: 2.141e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 1800, Train Loss: 1.998e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 1900, Train Loss: 5.700e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 2000, Train Loss: 1.530e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 2100, Train Loss: 1.126e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 2200, Train Loss: 2.140e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2300, Train Loss: 3.912e-01, Train Accuracy: 0.844
# Epoch: 2, Step: 2400, Train Loss: 3.343e-01, Train Accuracy: 0.844
# Epoch: 2, Step: 2500, Train Loss: 3.831e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 2600, Train Loss: 4.146e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 2700, Train Loss: 2.325e-01, Train Accuracy: 0.875
# epoch: 2	 train_loss: 2.711e-01	 train_accuracy:0.894	 val_loss: 2.741e-01	 val_accuracy:0.891
# Epoch: 3, Step: 2800, Train Loss: 1.517e-01, Train Accuracy: 1.000
# Epoch: 3, Step: 2900, Train Loss: 1.531e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3000, Train Loss: 2.117e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3100, Train Loss: 2.564e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3200, Train Loss: 3.687e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3300, Train Loss: 1.676e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3400, Train Loss: 1.969e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3500, Train Loss: 1.500e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3600, Train Loss: 3.020e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3700, Train Loss: 2.619e-01, Train Accuracy: 0.844
# Epoch: 3, Step: 3800, Train Loss: 2.047e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3900, Train Loss: 3.198e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 4000, Train Loss: 2.973e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 4100, Train Loss: 4.047e-01, Train Accuracy: 0.812
# epoch: 3	 train_loss: 2.630e-01	 train_accuracy:0.895	 val_loss: 2.733e-01	 val_accuracy:0.897
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅█████████████</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▇█</td></tr><tr><td>train_accuracy_step</td><td>▂▅▆▆▇▂▂▆▃▂▅▅▂▃▃▆▇▅▁▇▇▅▂▂▃▃▃█▆▅▃▅▆▆▆▅▂▅▁▁</td></tr><tr><td>train_loss</td><td>█▃▁</td></tr><tr><td>train_loss_step</td><td>▅▃▃▂▂▅▄▂▄▃▂▄▄▄▄▃▃▂█▂▁▃▅▄▅▆▃▂▂▃▃▅▂▂▂▄▃▂▄▅</td></tr><tr><td>val_accuracy</td><td>▆▁█</td></tr><tr><td>val_loss</td><td>█▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>3</td></tr><tr><td>global_step</td><td>4100</td></tr><tr><td>train_accuracy</td><td>0.89525</td></tr><tr><td>train_accuracy_step</td><td>0.8125</td></tr><tr><td>train_loss</td><td>0.26298</td></tr><tr><td>train_loss_step</td><td>0.4047</td></tr><tr><td>val_accuracy</td><td>0.89662</td></tr><tr><td>val_loss</td><td>0.27334</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">flowing-puddle-24</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/tyfc735p' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/tyfc735p</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_204248-tyfc735p/logs</code>
# ==================================================
# Training and evaluating ModernBERT model
# ==================================================
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_204830-bicnmcd6</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/bicnmcd6' target="_blank">vivid-tree-25</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/bicnmcd6' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/bicnmcd6</a>
# config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/599M [00:00<?, ?B/s]
# Model trainable parameters: 98690
# W0325 20:48:48.060000 535 torch/_inductor/utils.py:1137] [1/0] Not enough SMs to use max_autotune_gemm mode
# Epoch: 1, Step: 100, Train Loss: 6.223e-01, Train Accuracy: 0.750
# Epoch: 1, Step: 200, Train Loss: 5.656e-01, Train Accuracy: 0.719
# Epoch: 1, Step: 300, Train Loss: 1.991e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 400, Train Loss: 3.309e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 500, Train Loss: 2.957e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 600, Train Loss: 2.619e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 700, Train Loss: 3.086e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 800, Train Loss: 1.548e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 900, Train Loss: 4.826e-01, Train Accuracy: 0.781
# Epoch: 1, Step: 1000, Train Loss: 5.075e-01, Train Accuracy: 0.781
# Epoch: 1, Step: 1100, Train Loss: 1.750e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1200, Train Loss: 1.117e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 1300, Train Loss: 1.373e-01, Train Accuracy: 0.938
# epoch: 1	 train_loss: 2.987e-01	 train_accuracy:0.882	 val_loss: 2.721e-01	 val_accuracy:0.891
# Epoch: 2, Step: 1400, Train Loss: 5.241e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 1500, Train Loss: 4.375e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 1600, Train Loss: 2.715e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 1700, Train Loss: 2.535e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 1800, Train Loss: 2.029e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 1900, Train Loss: 8.398e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 2000, Train Loss: 4.289e-01, Train Accuracy: 0.844
# Epoch: 2, Step: 2100, Train Loss: 2.427e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2200, Train Loss: 2.853e-01, Train Accuracy: 0.781
# Epoch: 2, Step: 2300, Train Loss: 3.618e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 2400, Train Loss: 1.046e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 2500, Train Loss: 2.027e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2600, Train Loss: 2.762e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2700, Train Loss: 1.956e-01, Train Accuracy: 0.906
# epoch: 2	 train_loss: 2.655e-01	 train_accuracy:0.898	 val_loss: 2.532e-01	 val_accuracy:0.899
# Epoch: 3, Step: 2800, Train Loss: 1.356e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 2900, Train Loss: 1.776e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3000, Train Loss: 1.579e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3100, Train Loss: 2.644e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3200, Train Loss: 2.797e-01, Train Accuracy: 0.844
# Epoch: 3, Step: 3300, Train Loss: 1.859e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3400, Train Loss: 4.813e-01, Train Accuracy: 0.781
# Epoch: 3, Step: 3500, Train Loss: 4.930e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3600, Train Loss: 6.178e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 3700, Train Loss: 1.154e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3800, Train Loss: 2.671e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3900, Train Loss: 4.466e-01, Train Accuracy: 0.844
# Epoch: 3, Step: 4000, Train Loss: 2.017e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 4100, Train Loss: 3.469e-01, Train Accuracy: 0.844
# epoch: 3	 train_loss: 2.575e-01	 train_accuracy:0.901	 val_loss: 2.493e-01	 val_accuracy:0.905
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅█████████████</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▇█</td></tr><tr><td>train_accuracy_step</td><td>▂▁▇▅▄▄▆▆▃▃▆▇▆▃▃▆▅▆█▄▆▃▃▇▆▆▆▆▅▆▆▄▆▃▅█▆▆▄▄</td></tr><tr><td>train_loss</td><td>█▂▁</td></tr><tr><td>train_loss_step</td><td>█▇▃▄▄▃▄▂▆▇▂▂▂▇▆▄▃▃▁▆▃▄▅▂▃▄▃▂▂▂▄▄▃▆▆▁▂▄▆▅</td></tr><tr><td>val_accuracy</td><td>▁▅█</td></tr><tr><td>val_loss</td><td>█▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>3</td></tr><tr><td>global_step</td><td>4100</td></tr><tr><td>train_accuracy</td><td>0.90072</td></tr><tr><td>train_accuracy_step</td><td>0.84375</td></tr><tr><td>train_loss</td><td>0.25751</td></tr><tr><td>train_loss_step</td><td>0.34687</td></tr><tr><td>val_accuracy</td><td>0.90528</td></tr><tr><td>val_loss</td><td>0.24926</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vivid-tree-25</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/bicnmcd6' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1/runs/bicnmcd6</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task1</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_204830-bicnmcd6/logs</code>
# Model Selection Results:
# Model      Validation Accuracy  Validation Loss
# ---------------------------------------------
# BERT       0.8966                0.2733
# ModernBERT 0.9053                0.2493

# %%
# TODO: Get the best model from Task 1 results
# 1. Find the model with the highest validation accuracy in task1_results
# 2. Extract the model, model_name, and tokenizer from the best result
# 3. Print information about which model will be used for further tasks

# Get the best model from Task 1 results
# 1. Find the model with the highest validation accuracy in task1_results
best_result = max(task1_results, key=lambda x: x['val_accuracy'])

# 2. Extract the model, model_name, and tokenizer from the best result
best_model = best_result['model']
best_model_name = best_result['model_name']
best_tokenizer = best_result['tokenizer']

# 3. Print information about which model will be used for further tasks
print(f"\nBest model from Task 1: {best_model_name}")
print(f"Using {best_model_name} for further tasks")
# Out:
# Best model from Task 1: answerdotai/ModernBERT-base
# Using answerdotai/ModernBERT-base for further tasks

# %% [markdown]
# ## Task 2: Hyperparameter Tuning
#
# Now that we have selected the best model architecture, let's tune its hyperparameters to optimize performance.
#
# In this task, you'll experiment with different hyperparameter configurations to find the best model. You should explore variations in:
#
# - **Hidden layer sizes**: Try different sizes for the hidden layers in your classifier (e.g., 64, 128, 256, 512)
# - **Number of hidden layers**: Experiment with adding more layers to your classifier (e.g., 1, 2, 3 layers)
# - **Batch sizes**: Test different batch sizes (e.g., 16, 32, 64) - note that larger batch sizes may cause memory issues
# - **Learning rates**: Try different learning rates (e.g., 1e-3, 5e-4, 1e-4)
# - **Freezing base parameters**: Experiment with keeping the whole base model frozen vs unfreezing just the top 5 layers of the base model.
# - **Optimizer**: You can try different optimizers like Adam, AdamW, or SGD
#
# You should run at least 5 different hyperparameter configurations and track their performance using wandb. Below is a template for setting up your experiments.

# %%
# Define your hyperparameter configurations to test
# You should define at least 5 different configurations to explore the hyperparameter space
hp_configs = [
    # Configuration 1 (baseline)
    {
        "config_name": "Baseline",
        "hidden_size": 128,
        "num_layers": 1,
        "batch_size": 32,
        "optimizer": "Adam",
        "learning_rate": 1e-3,
        "weight_decay": 1e-4,  # Do NOT change
        "freeze_base": True,
        "num_epochs": 5        # Do NOT change
    },

    # Configuration 1 - MODIFY THIS!
    {
        "config_name": "Config 1",
        "hidden_size": 256,    # Increased hidden size
        "num_layers": 2,       # Added an extra layer
        "batch_size": 16,      # Reduced batch size
        "optimizer": "AdamW",  # Changed optimizer
        "freeze_base": False,  # Unfreeze base model
        "learning_rate": 5e-4, # Adjusted learning rate
        "weight_decay": 1e-4,  # Do NOT change
        "num_epochs": 5        # Do NOT change
    },

    # Configuration 2 - MODIFY THIS!
    {
        "config_name": "Config 2",
        "hidden_size": 512,    # Increased hidden size
        "num_layers": 1,       # Single layer
        "batch_size": 64,      # Increased batch size
        "optimizer": "SGD",    # Changed optimizer
        "freeze_base": True,   # Freeze base model
        "learning_rate": 1e-4, # Reduced learning rate
        "weight_decay": 1e-4,  # Do NOT change
        "num_epochs": 5        # Do NOT change
    },

    # Configuration 3 - MODIFY THIS!
    {
        "config_name": "Config 3",
        "hidden_size": 64,     # Reduced hidden size
        "num_layers": 3,       # Added more layers
        "batch_size": 32,      # Default batch size
        "optimizer": "Adam",   # Default optimizer
        "freeze_base": False,  # Unfreeze base model
        "learning_rate": 1e-3, # Default learning rate
        "weight_decay": 1e-4,  # Do NOT change
        "num_epochs": 5        # Do NOT change
    },

    # Configuration 4 - MODIFY THIS!
    {
        "config_name": "Config 4",
        "hidden_size": 128,    # Default hidden size
        "num_layers": 2,       # Added an extra layer
        "batch_size": 16,      # Reduced batch size
        "optimizer": "AdamW",  # Changed optimizer
        "freeze_base": True,   # Freeze base model
        "learning_rate": 1e-4, # Reduced learning rate
        "weight_decay": 1e-4,  # Do NOT change
        "num_epochs": 5        # Do NOT change
    },
    # Configuration 5 - MODIFY THIS!
    {
        "config_name": "Config 5",
        "hidden_size": 32,    # Default hidden size
        "num_layers": 2,       # Added an extra layer
        "batch_size": 16,      # Reduced batch size
        "optimizer": "Adam",  # Changed optimizer
        "freeze_base": False,   # Freeze base model
        "learning_rate": 1e-4, # Reduced learning rate
        "weight_decay": 1e-4,  # Do NOT change
        "num_epochs": 5        # Do NOT change
    }
]

# %%
def run_hyperparameter_tuning(model_name, base_tokenizer):
    """
    Run hyperparameter tuning experiments

    Args:
        model_name: Name of the model to use
        base_tokenizer: Tokenizer for the model

    Returns:
        List of experiment results
    """
    print(f"\n{'='*50}")
    print(f"Running Hyperparameter Tuning for {model_name}")
    print(f"{'='*50}")

    results = []
    best_val_acc = 0
    best_config_idx = 0
    best_model = None

    # For each configuration in your hp_configs list
    for i, config in enumerate(hp_configs):
        print(f"\nRunning experiment {i+1}/{len(hp_configs)}: {config['config_name']}")

        # Initialize wandb for this experiment
        wandb_config = {**config, "model_name": model_name}
        init_wandb(wandb_config, "clickbait-detection-task2")

        # Create model with this configuration
        model = get_model(
            model_name=model_name,
            num_classes=2,
            freeze_base=config["freeze_base"],
            hidden_size=config["hidden_size"],
            num_layers=config["num_layers"]
        )

        # Train model
        model, logs = train(
            model=model,
            train_dataset=dataset['train'],
            val_dataset=dataset['validation'],
            num_epochs=config["num_epochs"],
            batch_size=config["batch_size"],
            optimizer_cls=config["optimizer"],
            lr=config["learning_rate"],
            weight_decay=config["weight_decay"],
            device=device,
            tokenizer=base_tokenizer,
            use_wandb=True
        )

        # Evaluate on validation set
        val_loss, val_acc, _, _, _ = evaluate(
            model=model,
            dataset=dataset['validation'],
            batch_size=config["batch_size"],
            device=device,
            tokenizer=base_tokenizer
        )

        # Log final validation metrics
        wandb.log({
            "final_val_loss": val_loss,
            "final_val_accuracy": val_acc
        })

        # Finish wandb run
        wandb.finish()

        # Record results
        results.append({
            "config_name": config["config_name"],
            "hidden_size": config["hidden_size"],
            "num_layers": config["num_layers"],
            "batch_size": config["batch_size"],
            "learning_rate": config["learning_rate"],
            "weight_decay": config["weight_decay"],
            "optimizer": config["optimizer"],
            "val_loss": val_loss,
            "val_accuracy": val_acc,
            "model": model
        })

        # Keep track of best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_config_idx = i
            best_model = model

    # Display results in a table
    print("\nHyperparameter Tuning Results:")
    print("-" * 120)
    print(f"{'Config':<10} {'Hidden Size':<12} {'Layers':<8} {'Batch Size':<12} {'Learning Rate':<14} {'Weight Decay':<14} {'Optimizer':<10} {'Val Accuracy':<15}")
    print("-" * 120)

    for result in results:
        print(f"{result['config_name']:<10} {result['hidden_size']:<12} {result['num_layers']:<8} {result['batch_size']:<12} {result['learning_rate']:<14} {result['weight_decay']:<14} {result['optimizer']:<10} {result['val_accuracy']:.4f}")

    print("-" * 120)
    print(f"Best configuration: {results[best_config_idx]['config_name']} with validation accuracy: {best_val_acc:.4f}")

    return results, best_model, best_config_idx

# %%
# Run Task 2: Hyperparameter Tuning
# Run all hyperparameter experiments
tuning_results, best_tuned_model, best_config_idx = run_hyperparameter_tuning(best_model_name, best_tokenizer)
# Out:
# ==================================================
# Running Hyperparameter Tuning for answerdotai/ModernBERT-base
# ==================================================
#
# Running experiment 1/6: Baseline
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_205713-u0joth6q</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/u0joth6q' target="_blank">fluent-pine-41</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/u0joth6q' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/u0joth6q</a>
# Epoch: 1, Step: 100, Train Loss: 4.093e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 200, Train Loss: 2.605e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 300, Train Loss: 3.315e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 400, Train Loss: 2.737e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 500, Train Loss: 1.765e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 600, Train Loss: 2.064e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 700, Train Loss: 1.687e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 800, Train Loss: 2.066e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 900, Train Loss: 3.053e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 1000, Train Loss: 3.278e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 1100, Train Loss: 1.584e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 1200, Train Loss: 3.128e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 1300, Train Loss: 2.775e-01, Train Accuracy: 0.906
# epoch: 1	 train_loss: 2.997e-01	 train_accuracy:0.882	 val_loss: 2.773e-01	 val_accuracy:0.888
# Epoch: 2, Step: 1400, Train Loss: 3.074e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 1500, Train Loss: 1.726e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 1600, Train Loss: 1.362e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 1700, Train Loss: 4.322e-01, Train Accuracy: 0.844
# Epoch: 2, Step: 1800, Train Loss: 2.301e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 1900, Train Loss: 1.398e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 2000, Train Loss: 2.850e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 2100, Train Loss: 3.582e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 2200, Train Loss: 5.435e-01, Train Accuracy: 0.750
# Epoch: 2, Step: 2300, Train Loss: 3.533e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2400, Train Loss: 4.071e-01, Train Accuracy: 0.781
# Epoch: 2, Step: 2500, Train Loss: 2.600e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 2600, Train Loss: 2.328e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2700, Train Loss: 2.429e-01, Train Accuracy: 0.906
# epoch: 2	 train_loss: 2.678e-01	 train_accuracy:0.897	 val_loss: 2.557e-01	 val_accuracy:0.902
# Epoch: 3, Step: 2800, Train Loss: 2.173e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 2900, Train Loss: 3.862e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3000, Train Loss: 1.319e-01, Train Accuracy: 0.969
# Epoch: 3, Step: 3100, Train Loss: 5.118e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 3200, Train Loss: 3.521e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3300, Train Loss: 4.984e-01, Train Accuracy: 0.781
# Epoch: 3, Step: 3400, Train Loss: 1.804e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3500, Train Loss: 4.102e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3600, Train Loss: 1.693e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3700, Train Loss: 2.413e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3800, Train Loss: 2.779e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3900, Train Loss: 2.151e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 4000, Train Loss: 2.121e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 4100, Train Loss: 3.888e-01, Train Accuracy: 0.875
# epoch: 3	 train_loss: 2.558e-01	 train_accuracy:0.902	 val_loss: 2.596e-01	 val_accuracy:0.894
# Epoch: 4, Step: 4200, Train Loss: 3.921e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 4300, Train Loss: 3.074e-01, Train Accuracy: 0.844
# Epoch: 4, Step: 4400, Train Loss: 6.542e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 4500, Train Loss: 2.705e-01, Train Accuracy: 0.906
# Epoch: 4, Step: 4600, Train Loss: 5.335e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 4700, Train Loss: 1.726e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 4800, Train Loss: 1.225e-01, Train Accuracy: 0.969
# Epoch: 4, Step: 4900, Train Loss: 1.881e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 5000, Train Loss: 3.409e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 5100, Train Loss: 3.107e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 5200, Train Loss: 2.094e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 5300, Train Loss: 1.537e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 5400, Train Loss: 3.137e-01, Train Accuracy: 0.875
# epoch: 4	 train_loss: 2.494e-01	 train_accuracy:0.904	 val_loss: 2.515e-01	 val_accuracy:0.901
# Epoch: 5, Step: 5500, Train Loss: 3.261e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 5600, Train Loss: 2.805e-01, Train Accuracy: 0.906
# Epoch: 5, Step: 5700, Train Loss: 3.497e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 5800, Train Loss: 2.999e-01, Train Accuracy: 0.906
# Epoch: 5, Step: 5900, Train Loss: 1.935e-01, Train Accuracy: 0.969
# Epoch: 5, Step: 6000, Train Loss: 2.104e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 6100, Train Loss: 3.451e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 6200, Train Loss: 3.572e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 6300, Train Loss: 3.251e-01, Train Accuracy: 0.844
# Epoch: 5, Step: 6400, Train Loss: 1.359e-01, Train Accuracy: 0.969
# Epoch: 5, Step: 6500, Train Loss: 2.447e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 6600, Train Loss: 1.577e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 6700, Train Loss: 2.954e-01, Train Accuracy: 0.906
# Epoch: 5, Step: 6800, Train Loss: 2.335e-01, Train Accuracy: 0.844
# epoch: 5	 train_loss: 2.447e-01	 train_accuracy:0.905	 val_loss: 2.607e-01	 val_accuracy:0.902
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆███████</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▅▇██</td></tr><tr><td>train_accuracy_step</td><td>▄▅▆▇▅▄▅▅▇▇▅▇▅▅▁▂▅▅▅▇▂▅▅▅▅▅▄█▃▇▅▆▆▅▆▅▅▇▇▅</td></tr><tr><td>train_loss</td><td>█▄▂▂▁</td></tr><tr><td>train_loss_step</td><td>▆▄▃▂▂▄▄▁▃▄▃▁▄▅█▃▂▅▇▅▆▂▃▃▂▃█▂▂▅▂▁▄▃▅▂▂▅▁▃</td></tr><tr><td>val_accuracy</td><td>▁█▄██</td></tr><tr><td>val_loss</td><td>█▂▃▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>final_val_accuracy</td><td>0.90166</td></tr><tr><td>final_val_loss</td><td>0.26068</td></tr><tr><td>global_step</td><td>6800</td></tr><tr><td>train_accuracy</td><td>0.90526</td></tr><tr><td>train_accuracy_step</td><td>0.84375</td></tr><tr><td>train_loss</td><td>0.24467</td></tr><tr><td>train_loss_step</td><td>0.23347</td></tr><tr><td>val_accuracy</td><td>0.90166</td></tr><tr><td>val_loss</td><td>0.26068</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fluent-pine-41</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/u0joth6q' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/u0joth6q</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_205713-u0joth6q/logs</code>
# Running experiment 2/6: Config 1
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_211112-nnumss3y</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/nnumss3y' target="_blank">pleasant-snowball-42</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/nnumss3y' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/nnumss3y</a>
# Unfroze the last 5 layers out of 22 total layers.
# Epoch: 1, Step: 100, Train Loss: 4.219e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 200, Train Loss: 6.072e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 300, Train Loss: 3.629e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 400, Train Loss: 2.956e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 500, Train Loss: 1.412e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 600, Train Loss: 3.165e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 700, Train Loss: 5.439e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 800, Train Loss: 1.176e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 900, Train Loss: 1.683e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1000, Train Loss: 4.456e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1100, Train Loss: 1.863e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1200, Train Loss: 3.853e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1300, Train Loss: 3.920e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1400, Train Loss: 2.033e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1500, Train Loss: 1.665e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1600, Train Loss: 1.788e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1700, Train Loss: 2.216e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1800, Train Loss: 4.514e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 1900, Train Loss: 3.467e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2000, Train Loss: 4.577e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 2100, Train Loss: 2.653e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 2200, Train Loss: 5.110e-01, Train Accuracy: 0.750
# Epoch: 1, Step: 2300, Train Loss: 2.599e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2400, Train Loss: 3.218e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2500, Train Loss: 1.131e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2600, Train Loss: 2.029e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2700, Train Loss: 3.928e-01, Train Accuracy: 0.875
# epoch: 1	 train_loss: 2.432e-01	 train_accuracy:0.909	 val_loss: 2.480e-01	 val_accuracy:0.899
# Epoch: 2, Step: 2800, Train Loss: 2.066e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 2900, Train Loss: 8.409e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 3000, Train Loss: 9.697e-02, Train Accuracy: 0.938
# Epoch: 2, Step: 3100, Train Loss: 3.635e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3200, Train Loss: 2.398e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3300, Train Loss: 4.158e-01, Train Accuracy: 0.750
# Epoch: 2, Step: 3400, Train Loss: 1.275e-01, Train Accuracy: 1.000
# Epoch: 2, Step: 3500, Train Loss: 2.427e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3600, Train Loss: 1.956e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3700, Train Loss: 1.262e-01, Train Accuracy: 1.000
# Epoch: 2, Step: 3800, Train Loss: 5.778e-01, Train Accuracy: 0.688
# Epoch: 2, Step: 3900, Train Loss: 4.685e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 4000, Train Loss: 5.558e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 4100, Train Loss: 5.107e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4200, Train Loss: 4.173e-01, Train Accuracy: 0.688
# Epoch: 2, Step: 4300, Train Loss: 1.282e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4400, Train Loss: 2.092e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4500, Train Loss: 1.220e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4600, Train Loss: 4.569e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4700, Train Loss: 1.784e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4800, Train Loss: 3.207e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4900, Train Loss: 7.122e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 5000, Train Loss: 6.648e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 5100, Train Loss: 1.888e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 5200, Train Loss: 3.025e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 5300, Train Loss: 1.363e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5400, Train Loss: 1.565e-01, Train Accuracy: 0.938
# epoch: 2	 train_loss: 2.112e-01	 train_accuracy:0.921	 val_loss: 2.267e-01	 val_accuracy:0.907
# Epoch: 3, Step: 5500, Train Loss: 8.015e-02, Train Accuracy: 0.938
# Epoch: 3, Step: 5600, Train Loss: 3.438e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 5700, Train Loss: 1.675e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 5800, Train Loss: 4.143e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 5900, Train Loss: 2.891e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 6000, Train Loss: 4.915e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 6100, Train Loss: 1.525e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6200, Train Loss: 1.511e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6300, Train Loss: 2.888e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6400, Train Loss: 4.018e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6500, Train Loss: 1.944e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6600, Train Loss: 3.292e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6700, Train Loss: 3.861e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 6800, Train Loss: 4.304e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6900, Train Loss: 2.151e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7000, Train Loss: 6.940e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7100, Train Loss: 2.317e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7200, Train Loss: 2.486e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7300, Train Loss: 1.859e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7400, Train Loss: 3.574e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7500, Train Loss: 3.126e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7600, Train Loss: 1.781e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7700, Train Loss: 8.224e-02, Train Accuracy: 0.938
# Epoch: 3, Step: 7800, Train Loss: 2.568e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7900, Train Loss: 1.027e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8000, Train Loss: 1.732e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8100, Train Loss: 3.065e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8200, Train Loss: 2.842e-02, Train Accuracy: 1.000
# epoch: 3	 train_loss: 1.983e-01	 train_accuracy:0.923	 val_loss: 2.510e-01	 val_accuracy:0.905
# Epoch: 4, Step: 8300, Train Loss: 4.923e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 8400, Train Loss: 2.813e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8500, Train Loss: 3.285e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 8600, Train Loss: 1.064e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8700, Train Loss: 7.872e-02, Train Accuracy: 0.938
# Epoch: 4, Step: 8800, Train Loss: 1.347e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8900, Train Loss: 1.765e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9000, Train Loss: 6.694e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 9100, Train Loss: 1.500e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9200, Train Loss: 2.857e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9300, Train Loss: 2.311e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9400, Train Loss: 1.001e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9500, Train Loss: 1.776e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9600, Train Loss: 2.046e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9700, Train Loss: 1.439e-01, Train Accuracy: 1.000
# Epoch: 4, Step: 9800, Train Loss: 8.895e-02, Train Accuracy: 0.938
# Epoch: 4, Step: 9900, Train Loss: 2.788e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10000, Train Loss: 1.980e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10100, Train Loss: 1.372e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10200, Train Loss: 1.809e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 10300, Train Loss: 5.134e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10400, Train Loss: 5.532e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 10500, Train Loss: 1.155e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10600, Train Loss: 1.846e-01, Train Accuracy: 1.000
# Epoch: 4, Step: 10700, Train Loss: 2.650e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 10800, Train Loss: 2.293e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 10900, Train Loss: 1.426e-01, Train Accuracy: 0.938
# epoch: 4	 train_loss: 1.954e-01	 train_accuracy:0.922	 val_loss: 2.313e-01	 val_accuracy:0.910
# Epoch: 5, Step: 11000, Train Loss: 4.007e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11100, Train Loss: 3.627e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11200, Train Loss: 1.179e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11300, Train Loss: 8.503e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11400, Train Loss: 4.139e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11500, Train Loss: 2.012e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11600, Train Loss: 6.727e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11700, Train Loss: 9.789e-02, Train Accuracy: 0.938
# Epoch: 5, Step: 11800, Train Loss: 1.533e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11900, Train Loss: 4.516e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12000, Train Loss: 8.729e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 12100, Train Loss: 1.406e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12200, Train Loss: 1.792e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12300, Train Loss: 3.519e-01, Train Accuracy: 0.750
# Epoch: 5, Step: 12400, Train Loss: 9.146e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 12500, Train Loss: 2.134e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12600, Train Loss: 3.160e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 12700, Train Loss: 2.355e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12800, Train Loss: 1.599e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12900, Train Loss: 5.161e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 13000, Train Loss: 1.979e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13100, Train Loss: 2.121e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 13200, Train Loss: 1.668e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13300, Train Loss: 8.814e-02, Train Accuracy: 0.938
# Epoch: 5, Step: 13400, Train Loss: 8.531e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 13500, Train Loss: 1.759e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13600, Train Loss: 3.927e-02, Train Accuracy: 1.000
# epoch: 5	 train_loss: 1.828e-01	 train_accuracy:0.927	 val_loss: 2.575e-01	 val_accuracy:0.897
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆██████████</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▅▆▆█</td></tr><tr><td>train_accuracy_step</td><td>▅█▆▆▅▆▅▆▅▁██▃▆▆█▆▅█▅▆█▆▆▅▆▆▆█▆█▆█▆▅█▆▆▆▆</td></tr><tr><td>train_loss</td><td>█▄▃▂▁</td></tr><tr><td>train_loss_step</td><td>█▆▃▃▄█▄▂▂▄▁█▃▂▃▂▃▁▃▃▆▂▄▃▂▁▁▃▃▄▃▂▂▃▂▇▅▅▃▃</td></tr><tr><td>val_accuracy</td><td>▂▆▅█▁</td></tr><tr><td>val_loss</td><td>▆▁▇▂█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>final_val_accuracy</td><td>0.8969</td></tr><tr><td>final_val_loss</td><td>0.25753</td></tr><tr><td>global_step</td><td>13600</td></tr><tr><td>train_accuracy</td><td>0.92748</td></tr><tr><td>train_accuracy_step</td><td>1</td></tr><tr><td>train_loss</td><td>0.18275</td></tr><tr><td>train_loss_step</td><td>0.03927</td></tr><tr><td>val_accuracy</td><td>0.8969</td></tr><tr><td>val_loss</td><td>0.25753</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pleasant-snowball-42</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/nnumss3y' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/nnumss3y</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_211112-nnumss3y/logs</code>
# Running experiment 3/6: Config 2
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_212831-dsp0dwm1</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/dsp0dwm1' target="_blank">gentle-dragon-43</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/dsp0dwm1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/dsp0dwm1</a>
# Epoch: 1, Step: 100, Train Loss: 6.386e-01, Train Accuracy: 0.672
# Epoch: 1, Step: 200, Train Loss: 6.129e-01, Train Accuracy: 0.688
# Epoch: 1, Step: 300, Train Loss: 6.615e-01, Train Accuracy: 0.562
# Epoch: 1, Step: 400, Train Loss: 6.864e-01, Train Accuracy: 0.516
# Epoch: 1, Step: 500, Train Loss: 6.307e-01, Train Accuracy: 0.609
# Epoch: 1, Step: 600, Train Loss: 5.796e-01, Train Accuracy: 0.734
# epoch: 1	 train_loss: 6.322e-01	 train_accuracy:0.625	 val_loss: 6.089e-01	 val_accuracy:0.629
# Epoch: 2, Step: 700, Train Loss: 5.922e-01, Train Accuracy: 0.641
# Epoch: 2, Step: 800, Train Loss: 5.640e-01, Train Accuracy: 0.703
# Epoch: 2, Step: 900, Train Loss: 6.360e-01, Train Accuracy: 0.531
# Epoch: 2, Step: 1000, Train Loss: 5.849e-01, Train Accuracy: 0.688
# Epoch: 2, Step: 1100, Train Loss: 5.607e-01, Train Accuracy: 0.703
# Epoch: 2, Step: 1200, Train Loss: 5.567e-01, Train Accuracy: 0.703
# Epoch: 2, Step: 1300, Train Loss: 5.630e-01, Train Accuracy: 0.672
# epoch: 2	 train_loss: 5.927e-01	 train_accuracy:0.646	 val_loss: 5.815e-01	 val_accuracy:0.679
# Epoch: 3, Step: 1400, Train Loss: 5.445e-01, Train Accuracy: 0.688
# Epoch: 3, Step: 1500, Train Loss: 5.435e-01, Train Accuracy: 0.719
# Epoch: 3, Step: 1600, Train Loss: 5.608e-01, Train Accuracy: 0.688
# Epoch: 3, Step: 1700, Train Loss: 6.231e-01, Train Accuracy: 0.703
# Epoch: 3, Step: 1800, Train Loss: 5.669e-01, Train Accuracy: 0.734
# Epoch: 3, Step: 1900, Train Loss: 5.572e-01, Train Accuracy: 0.703
# Epoch: 3, Step: 2000, Train Loss: 5.962e-01, Train Accuracy: 0.719
# epoch: 3	 train_loss: 5.671e-01	 train_accuracy:0.707	 val_loss: 5.601e-01	 val_accuracy:0.708
# Epoch: 4, Step: 2100, Train Loss: 6.112e-01, Train Accuracy: 0.703
# Epoch: 4, Step: 2200, Train Loss: 5.271e-01, Train Accuracy: 0.766
# Epoch: 4, Step: 2300, Train Loss: 5.982e-01, Train Accuracy: 0.656
# Epoch: 4, Step: 2400, Train Loss: 5.998e-01, Train Accuracy: 0.672
# Epoch: 4, Step: 2500, Train Loss: 5.243e-01, Train Accuracy: 0.750
# Epoch: 4, Step: 2600, Train Loss: 5.478e-01, Train Accuracy: 0.766
# Epoch: 4, Step: 2700, Train Loss: 5.851e-01, Train Accuracy: 0.703
# epoch: 4	 train_loss: 5.466e-01	 train_accuracy:0.753	 val_loss: 5.422e-01	 val_accuracy:0.777
# Epoch: 5, Step: 2800, Train Loss: 5.331e-01, Train Accuracy: 0.797
# Epoch: 5, Step: 2900, Train Loss: 5.108e-01, Train Accuracy: 0.828
# Epoch: 5, Step: 3000, Train Loss: 5.160e-01, Train Accuracy: 0.828
# Epoch: 5, Step: 3100, Train Loss: 5.259e-01, Train Accuracy: 0.828
# Epoch: 5, Step: 3200, Train Loss: 5.348e-01, Train Accuracy: 0.672
# Epoch: 5, Step: 3300, Train Loss: 5.199e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 3400, Train Loss: 5.213e-01, Train Accuracy: 0.750
# epoch: 5	 train_loss: 5.288e-01	 train_accuracy:0.791	 val_loss: 5.263e-01	 val_accuracy:0.801
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆████████</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train_accuracy</td><td>▁▂▄▆█</td></tr><tr><td>train_accuracy_step</td><td>▅▅▂▁▃▆▄▅▁▅▅▅▅▅▆▅▅▆▅▆▅▇▄▅▆▇▅▇███▅█▆</td></tr><tr><td>train_loss</td><td>█▅▄▂▁</td></tr><tr><td>train_loss_step</td><td>▆▅▇█▆▄▄▃▆▄▃▃▃▂▂▃▅▃▃▄▅▂▄▅▂▂▄▂▁▁▂▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▇█</td></tr><tr><td>val_loss</td><td>█▆▄▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>final_val_accuracy</td><td>0.80077</td></tr><tr><td>final_val_loss</td><td>0.52633</td></tr><tr><td>global_step</td><td>3400</td></tr><tr><td>train_accuracy</td><td>0.79109</td></tr><tr><td>train_accuracy_step</td><td>0.75</td></tr><tr><td>train_loss</td><td>0.52877</td></tr><tr><td>train_loss_step</td><td>0.52128</td></tr><tr><td>val_accuracy</td><td>0.80077</td></tr><tr><td>val_loss</td><td>0.52633</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gentle-dragon-43</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/dsp0dwm1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/dsp0dwm1</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_212831-dsp0dwm1/logs</code>
# Running experiment 4/6: Config 3
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_214641-6wotyz32</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/6wotyz32' target="_blank">dry-paper-44</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/6wotyz32' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/6wotyz32</a>
# Unfroze the last 5 layers out of 22 total layers.
# Epoch: 1, Step: 100, Train Loss: 2.287e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 200, Train Loss: 3.348e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 300, Train Loss: 2.642e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 400, Train Loss: 8.130e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 500, Train Loss: 2.798e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 600, Train Loss: 1.307e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 700, Train Loss: 8.572e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 800, Train Loss: 3.483e-01, Train Accuracy: 0.844
# Epoch: 1, Step: 900, Train Loss: 2.048e-01, Train Accuracy: 0.906
# Epoch: 1, Step: 1000, Train Loss: 1.235e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 1100, Train Loss: 1.053e-01, Train Accuracy: 0.969
# Epoch: 1, Step: 1200, Train Loss: 8.168e-02, Train Accuracy: 0.969
# Epoch: 1, Step: 1300, Train Loss: 5.117e-01, Train Accuracy: 0.844
# epoch: 1	 train_loss: 2.495e-01	 train_accuracy:0.908	 val_loss: 2.375e-01	 val_accuracy:0.907
# Epoch: 2, Step: 1400, Train Loss: 1.201e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 1500, Train Loss: 2.129e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 1600, Train Loss: 1.093e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 1700, Train Loss: 1.168e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 1800, Train Loss: 1.903e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 1900, Train Loss: 1.428e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 2000, Train Loss: 1.807e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 2100, Train Loss: 2.476e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2200, Train Loss: 2.475e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2300, Train Loss: 1.100e-01, Train Accuracy: 0.969
# Epoch: 2, Step: 2400, Train Loss: 3.975e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 2500, Train Loss: 1.692e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 2600, Train Loss: 2.910e-01, Train Accuracy: 0.906
# Epoch: 2, Step: 2700, Train Loss: 2.798e-01, Train Accuracy: 0.906
# epoch: 2	 train_loss: 2.163e-01	 train_accuracy:0.918	 val_loss: 2.271e-01	 val_accuracy:0.908
# Epoch: 3, Step: 2800, Train Loss: 1.153e-01, Train Accuracy: 0.969
# Epoch: 3, Step: 2900, Train Loss: 4.175e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 3000, Train Loss: 8.793e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 3100, Train Loss: 1.649e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 3200, Train Loss: 8.944e-02, Train Accuracy: 0.969
# Epoch: 3, Step: 3300, Train Loss: 1.210e-01, Train Accuracy: 0.969
# Epoch: 3, Step: 3400, Train Loss: 1.185e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 3500, Train Loss: 4.511e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 3600, Train Loss: 2.376e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3700, Train Loss: 4.203e-01, Train Accuracy: 0.844
# Epoch: 3, Step: 3800, Train Loss: 3.018e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 3900, Train Loss: 1.951e-01, Train Accuracy: 0.906
# Epoch: 3, Step: 4000, Train Loss: 1.888e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 4100, Train Loss: 1.322e-01, Train Accuracy: 0.969
# epoch: 3	 train_loss: 2.054e-01	 train_accuracy:0.921	 val_loss: 2.201e-01	 val_accuracy:0.913
# Epoch: 4, Step: 4200, Train Loss: 1.723e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 4300, Train Loss: 4.873e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 4400, Train Loss: 3.379e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 4500, Train Loss: 2.163e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 4600, Train Loss: 2.037e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 4700, Train Loss: 1.295e-01, Train Accuracy: 0.969
# Epoch: 4, Step: 4800, Train Loss: 1.705e-01, Train Accuracy: 0.969
# Epoch: 4, Step: 4900, Train Loss: 2.009e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 5000, Train Loss: 8.183e-02, Train Accuracy: 0.969
# Epoch: 4, Step: 5100, Train Loss: 2.710e-01, Train Accuracy: 0.906
# Epoch: 4, Step: 5200, Train Loss: 1.553e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 5300, Train Loss: 1.843e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 5400, Train Loss: 6.870e-01, Train Accuracy: 0.875
# epoch: 4	 train_loss: 1.960e-01	 train_accuracy:0.925	 val_loss: 2.330e-01	 val_accuracy:0.910
# Epoch: 5, Step: 5500, Train Loss: 1.367e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 5600, Train Loss: 1.018e-01, Train Accuracy: 0.969
# Epoch: 5, Step: 5700, Train Loss: 1.439e-01, Train Accuracy: 0.969
# Epoch: 5, Step: 5800, Train Loss: 1.644e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 5900, Train Loss: 1.636e-01, Train Accuracy: 0.906
# Epoch: 5, Step: 6000, Train Loss: 2.060e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 6100, Train Loss: 1.520e-01, Train Accuracy: 0.906
# Epoch: 5, Step: 6200, Train Loss: 1.262e-01, Train Accuracy: 0.969
# Epoch: 5, Step: 6300, Train Loss: 2.094e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 6400, Train Loss: 1.903e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 6500, Train Loss: 2.282e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 6600, Train Loss: 8.742e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 6700, Train Loss: 2.102e-01, Train Accuracy: 0.906
# Epoch: 5, Step: 6800, Train Loss: 2.403e-01, Train Accuracy: 0.906
# epoch: 5	 train_loss: 1.879e-01	 train_accuracy:0.927	 val_loss: 2.286e-01	 val_accuracy:0.911
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆███████</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▅▆▇█</td></tr><tr><td>train_accuracy_step</td><td>▆▅▅█▃█▂▅▇▇▆▇▅▆▇▅▇▆▅▁▇▂▃▅▆▃▃▇▇▆▅▃▃▆▇▆▆▇▃▅</td></tr><tr><td>train_loss</td><td>█▄▃▂▁</td></tr><tr><td>train_loss_step</td><td>▃▃▁▄▁▆▁▃▁▁▃▃▁▅▂▅▁▂▁▁▄▂▂▂▂▂▂▂▁▃▂█▂▁▂▂▂▂▃▃</td></tr><tr><td>val_accuracy</td><td>▁▁█▄▅</td></tr><tr><td>val_loss</td><td>█▄▁▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>final_val_accuracy</td><td>0.91117</td></tr><tr><td>final_val_loss</td><td>0.22861</td></tr><tr><td>global_step</td><td>6800</td></tr><tr><td>train_accuracy</td><td>0.92744</td></tr><tr><td>train_accuracy_step</td><td>0.90625</td></tr><tr><td>train_loss</td><td>0.18788</td></tr><tr><td>train_loss_step</td><td>0.24032</td></tr><tr><td>val_accuracy</td><td>0.91117</td></tr><tr><td>val_loss</td><td>0.22861</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dry-paper-44</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/6wotyz32' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/6wotyz32</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_214641-6wotyz32/logs</code>
# Running experiment 5/6: Config 4
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_220622-j750os41</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/j750os41' target="_blank">glamorous-firefly-45</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/j750os41' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/j750os41</a>
# Epoch: 1, Step: 100, Train Loss: 3.759e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 200, Train Loss: 2.342e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 300, Train Loss: 3.366e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 400, Train Loss: 4.158e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 500, Train Loss: 4.680e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 600, Train Loss: 2.483e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 700, Train Loss: 1.695e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 800, Train Loss: 2.694e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 900, Train Loss: 1.519e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1000, Train Loss: 2.320e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1100, Train Loss: 1.044e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 1200, Train Loss: 5.118e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 1300, Train Loss: 2.271e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1400, Train Loss: 3.985e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 1500, Train Loss: 3.552e-01, Train Accuracy: 0.750
# Epoch: 1, Step: 1600, Train Loss: 3.434e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1700, Train Loss: 6.625e-01, Train Accuracy: 0.750
# Epoch: 1, Step: 1800, Train Loss: 2.535e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1900, Train Loss: 1.321e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 2000, Train Loss: 1.151e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 2100, Train Loss: 3.625e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 2200, Train Loss: 1.966e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2300, Train Loss: 1.571e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2400, Train Loss: 1.409e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2500, Train Loss: 1.682e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2600, Train Loss: 2.900e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 2700, Train Loss: 4.138e-01, Train Accuracy: 0.812
# epoch: 1	 train_loss: 3.200e-01	 train_accuracy:0.873	 val_loss: 2.808e-01	 val_accuracy:0.890
# Epoch: 2, Step: 2800, Train Loss: 1.132e-01, Train Accuracy: 1.000
# Epoch: 2, Step: 2900, Train Loss: 2.789e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 3000, Train Loss: 3.210e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3100, Train Loss: 3.180e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3200, Train Loss: 1.514e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3300, Train Loss: 3.613e-01, Train Accuracy: 0.688
# Epoch: 2, Step: 3400, Train Loss: 2.684e-01, Train Accuracy: 0.750
# Epoch: 2, Step: 3500, Train Loss: 2.521e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3600, Train Loss: 5.826e-01, Train Accuracy: 0.750
# Epoch: 2, Step: 3700, Train Loss: 3.086e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3800, Train Loss: 4.059e-01, Train Accuracy: 0.750
# Epoch: 2, Step: 3900, Train Loss: 7.459e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 4000, Train Loss: 3.679e-01, Train Accuracy: 0.750
# Epoch: 2, Step: 4100, Train Loss: 1.591e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4200, Train Loss: 3.141e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4300, Train Loss: 4.600e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 4400, Train Loss: 9.479e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 4500, Train Loss: 1.854e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4600, Train Loss: 1.901e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4700, Train Loss: 1.361e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4800, Train Loss: 9.159e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 4900, Train Loss: 2.522e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5000, Train Loss: 2.110e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5100, Train Loss: 2.292e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5200, Train Loss: 2.634e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 5300, Train Loss: 4.973e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 5400, Train Loss: 2.326e-01, Train Accuracy: 0.938
# epoch: 2	 train_loss: 2.703e-01	 train_accuracy:0.895	 val_loss: 2.603e-01	 val_accuracy:0.896
# Epoch: 3, Step: 5500, Train Loss: 2.101e-01, Train Accuracy: 1.000
# Epoch: 3, Step: 5600, Train Loss: 4.704e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 5700, Train Loss: 1.112e-01, Train Accuracy: 1.000
# Epoch: 3, Step: 5800, Train Loss: 3.401e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 5900, Train Loss: 2.065e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6000, Train Loss: 1.126e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6100, Train Loss: 3.433e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 6200, Train Loss: 3.128e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6300, Train Loss: 1.870e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6400, Train Loss: 7.888e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 6500, Train Loss: 6.407e-01, Train Accuracy: 0.562
# Epoch: 3, Step: 6600, Train Loss: 1.741e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6700, Train Loss: 5.940e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6800, Train Loss: 1.555e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6900, Train Loss: 3.129e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7000, Train Loss: 3.774e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 7100, Train Loss: 3.905e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7200, Train Loss: 3.692e-01, Train Accuracy: 0.750
# Epoch: 3, Step: 7300, Train Loss: 2.017e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7400, Train Loss: 3.328e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 7500, Train Loss: 1.190e-01, Train Accuracy: 1.000
# Epoch: 3, Step: 7600, Train Loss: 4.233e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 7700, Train Loss: 2.695e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7800, Train Loss: 1.212e-01, Train Accuracy: 1.000
# Epoch: 3, Step: 7900, Train Loss: 1.434e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8000, Train Loss: 1.527e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 8100, Train Loss: 1.044e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8200, Train Loss: 3.718e-01, Train Accuracy: 0.875
# epoch: 3	 train_loss: 2.580e-01	 train_accuracy:0.900	 val_loss: 2.575e-01	 val_accuracy:0.900
# Epoch: 4, Step: 8300, Train Loss: 7.739e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 8400, Train Loss: 1.646e-01, Train Accuracy: 1.000
# Epoch: 4, Step: 8500, Train Loss: 4.078e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 8600, Train Loss: 4.050e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 8700, Train Loss: 3.120e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 8800, Train Loss: 1.718e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8900, Train Loss: 1.839e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9000, Train Loss: 1.474e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9100, Train Loss: 1.374e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9200, Train Loss: 2.434e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9300, Train Loss: 2.689e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9400, Train Loss: 3.715e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 9500, Train Loss: 1.315e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9600, Train Loss: 1.354e-01, Train Accuracy: 1.000
# Epoch: 4, Step: 9700, Train Loss: 1.521e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9800, Train Loss: 4.051e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 9900, Train Loss: 3.910e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 10000, Train Loss: 4.418e-01, Train Accuracy: 0.750
# Epoch: 4, Step: 10100, Train Loss: 2.430e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10200, Train Loss: 2.777e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 10300, Train Loss: 1.629e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10400, Train Loss: 1.751e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10500, Train Loss: 2.316e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 10600, Train Loss: 1.076e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10700, Train Loss: 3.047e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 10800, Train Loss: 3.864e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 10900, Train Loss: 4.324e-01, Train Accuracy: 0.750
# epoch: 4	 train_loss: 2.485e-01	 train_accuracy:0.904	 val_loss: 2.591e-01	 val_accuracy:0.905
# Epoch: 5, Step: 11000, Train Loss: 3.390e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11100, Train Loss: 2.065e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11200, Train Loss: 4.796e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 11300, Train Loss: 4.031e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11400, Train Loss: 9.874e-02, Train Accuracy: 0.938
# Epoch: 5, Step: 11500, Train Loss: 2.000e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11600, Train Loss: 4.782e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 11700, Train Loss: 2.064e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11800, Train Loss: 4.483e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11900, Train Loss: 1.376e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12000, Train Loss: 2.027e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12100, Train Loss: 2.133e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12200, Train Loss: 1.599e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12300, Train Loss: 8.937e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 12400, Train Loss: 5.389e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12500, Train Loss: 1.639e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12600, Train Loss: 3.158e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12700, Train Loss: 2.066e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12800, Train Loss: 1.577e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12900, Train Loss: 7.796e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 13000, Train Loss: 3.429e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 13100, Train Loss: 3.069e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13200, Train Loss: 5.406e-01, Train Accuracy: 0.750
# Epoch: 5, Step: 13300, Train Loss: 9.819e-02, Train Accuracy: 0.938
# Epoch: 5, Step: 13400, Train Loss: 1.514e-01, Train Accuracy: 1.000
# Epoch: 5, Step: 13500, Train Loss: 7.926e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 13600, Train Loss: 7.672e-02, Train Accuracy: 1.000
# epoch: 5	 train_loss: 2.427e-01	 train_accuracy:0.906	 val_loss: 2.624e-01	 val_accuracy:0.896
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆██████</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▃▃▃▃▃▃▃▃▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>train_accuracy</td><td>▁▆▇██</td></tr><tr><td>train_accuracy_step</td><td>█▅█▄▄▅▄▇▄▁▇▂█▄▇▄▄▇▄▇▅▄▅▇█▄▇▅▅▇▄▅▇▄▂▄▅▇▇▇</td></tr><tr><td>train_loss</td><td>█▃▂▂▁</td></tr><tr><td>train_loss_step</td><td>▃▄▅▂▅▄█▄▅▃▃▄▂▂▂▃▃▆▁▂▂▄▅▅▅▁▂▅▂▂▂▅▃▆▅▃▂▂▁▇</td></tr><tr><td>val_accuracy</td><td>▁▄▆█▄</td></tr><tr><td>val_loss</td><td>█▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>final_val_accuracy</td><td>0.89595</td></tr><tr><td>final_val_loss</td><td>0.26241</td></tr><tr><td>global_step</td><td>13600</td></tr><tr><td>train_accuracy</td><td>0.9063</td></tr><tr><td>train_accuracy_step</td><td>1</td></tr><tr><td>train_loss</td><td>0.24267</td></tr><tr><td>train_loss_step</td><td>0.07672</td></tr><tr><td>val_accuracy</td><td>0.89595</td></tr><tr><td>val_loss</td><td>0.26241</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glamorous-firefly-45</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/j750os41' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/j750os41</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_220622-j750os41/logs</code>
# Running experiment 6/6: Config 5
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250325_221805-owku1nn1</code>
# Syncing run <strong><a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/owku1nn1' target="_blank">genial-sponge-46</a></strong> to <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a>
#  View run at <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/owku1nn1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/owku1nn1</a>
# Unfroze the last 5 layers out of 22 total layers.
# Epoch: 1, Step: 100, Train Loss: 2.666e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 200, Train Loss: 7.686e-01, Train Accuracy: 0.688
# Epoch: 1, Step: 300, Train Loss: 2.469e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 400, Train Loss: 4.307e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 500, Train Loss: 1.394e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 600, Train Loss: 2.851e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 700, Train Loss: 1.504e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 800, Train Loss: 4.758e-01, Train Accuracy: 0.688
# Epoch: 1, Step: 900, Train Loss: 2.854e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1000, Train Loss: 2.671e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1100, Train Loss: 4.357e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 1200, Train Loss: 1.646e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 1300, Train Loss: 1.609e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1400, Train Loss: 3.722e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1500, Train Loss: 4.657e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1600, Train Loss: 2.304e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1700, Train Loss: 4.392e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 1800, Train Loss: 1.553e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1900, Train Loss: 2.778e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2000, Train Loss: 1.535e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2100, Train Loss: 2.143e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2200, Train Loss: 2.684e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2300, Train Loss: 2.247e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2400, Train Loss: 2.323e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2500, Train Loss: 9.182e-02, Train Accuracy: 0.938
# Epoch: 1, Step: 2600, Train Loss: 1.803e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2700, Train Loss: 6.118e-02, Train Accuracy: 1.000
# epoch: 1	 train_loss: 2.440e-01	 train_accuracy:0.908	 val_loss: 2.308e-01	 val_accuracy:0.908
# Epoch: 2, Step: 2800, Train Loss: 2.843e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 2900, Train Loss: 9.162e-02, Train Accuracy: 0.938
# Epoch: 2, Step: 3000, Train Loss: 4.833e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 3100, Train Loss: 1.177e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3200, Train Loss: 1.987e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3300, Train Loss: 9.496e-02, Train Accuracy: 0.938
# Epoch: 2, Step: 3400, Train Loss: 1.381e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3500, Train Loss: 1.366e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3600, Train Loss: 2.708e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3700, Train Loss: 1.533e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3800, Train Loss: 1.309e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3900, Train Loss: 2.941e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4000, Train Loss: 1.438e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4100, Train Loss: 2.958e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4200, Train Loss: 2.790e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4300, Train Loss: 3.590e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 4400, Train Loss: 1.695e-01, Train Accuracy: 1.000
# Epoch: 2, Step: 4500, Train Loss: 1.560e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4600, Train Loss: 5.584e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 4700, Train Loss: 3.522e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 4800, Train Loss: 5.927e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4900, Train Loss: 2.278e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 5000, Train Loss: 1.480e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5100, Train Loss: 2.118e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5200, Train Loss: 1.894e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5300, Train Loss: 6.766e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 5400, Train Loss: 2.288e-01, Train Accuracy: 0.875
# epoch: 2	 train_loss: 1.995e-01	 train_accuracy:0.923	 val_loss: 2.221e-01	 val_accuracy:0.911
# Epoch: 3, Step: 5500, Train Loss: 1.993e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 5600, Train Loss: 3.606e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 5700, Train Loss: 2.324e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 5800, Train Loss: 1.606e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 5900, Train Loss: 2.286e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 6000, Train Loss: 2.570e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 6100, Train Loss: 2.761e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6200, Train Loss: 3.773e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 6300, Train Loss: 2.437e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 6400, Train Loss: 1.324e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6500, Train Loss: 3.120e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6600, Train Loss: 2.421e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 6700, Train Loss: 2.873e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 6800, Train Loss: 1.578e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6900, Train Loss: 2.895e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7000, Train Loss: 1.583e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7100, Train Loss: 2.171e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7200, Train Loss: 5.582e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7300, Train Loss: 2.213e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7400, Train Loss: 2.833e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7500, Train Loss: 5.684e-01, Train Accuracy: 0.688
# Epoch: 3, Step: 7600, Train Loss: 2.645e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7700, Train Loss: 2.180e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7800, Train Loss: 7.457e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7900, Train Loss: 4.792e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 8000, Train Loss: 1.464e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8100, Train Loss: 1.888e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8200, Train Loss: 2.537e-02, Train Accuracy: 1.000
# epoch: 3	 train_loss: 1.801e-01	 train_accuracy:0.930	 val_loss: 2.275e-01	 val_accuracy:0.910
# Epoch: 4, Step: 8300, Train Loss: 1.142e-01, Train Accuracy: 1.000
# Epoch: 4, Step: 8400, Train Loss: 3.471e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 8500, Train Loss: 3.632e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 8600, Train Loss: 1.046e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8700, Train Loss: 7.614e-02, Train Accuracy: 0.938
# Epoch: 4, Step: 8800, Train Loss: 2.125e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8900, Train Loss: 7.859e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 9000, Train Loss: 2.240e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9100, Train Loss: 7.930e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 9200, Train Loss: 7.905e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 9300, Train Loss: 1.105e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9400, Train Loss: 6.516e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 9500, Train Loss: 2.095e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9600, Train Loss: 4.779e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 9700, Train Loss: 9.124e-02, Train Accuracy: 0.938
# Epoch: 4, Step: 9800, Train Loss: 3.668e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9900, Train Loss: 2.620e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10000, Train Loss: 7.572e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10100, Train Loss: 8.095e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10200, Train Loss: 5.861e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 10300, Train Loss: 1.846e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10400, Train Loss: 7.178e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10500, Train Loss: 7.744e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10600, Train Loss: 1.709e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10700, Train Loss: 3.333e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10800, Train Loss: 1.082e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10900, Train Loss: 3.394e-01, Train Accuracy: 0.875
# epoch: 4	 train_loss: 1.598e-01	 train_accuracy:0.938	 val_loss: 2.463e-01	 val_accuracy:0.904
# Epoch: 5, Step: 11000, Train Loss: 1.278e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11100, Train Loss: 2.687e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11200, Train Loss: 1.926e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11300, Train Loss: 1.735e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11400, Train Loss: 8.996e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11500, Train Loss: 5.597e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11600, Train Loss: 5.531e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11700, Train Loss: 5.645e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11800, Train Loss: 1.162e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11900, Train Loss: 1.030e-01, Train Accuracy: 1.000
# Epoch: 5, Step: 12000, Train Loss: 2.380e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12100, Train Loss: 1.103e-01, Train Accuracy: 1.000
# Epoch: 5, Step: 12200, Train Loss: 2.041e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12300, Train Loss: 2.894e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 12400, Train Loss: 1.011e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12500, Train Loss: 2.259e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12600, Train Loss: 3.391e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 12700, Train Loss: 1.627e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12800, Train Loss: 1.598e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12900, Train Loss: 5.428e-02, Train Accuracy: 0.938
# Epoch: 5, Step: 13000, Train Loss: 1.116e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13100, Train Loss: 8.927e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 13200, Train Loss: 4.064e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 13300, Train Loss: 9.921e-02, Train Accuracy: 0.938
# Epoch: 5, Step: 13400, Train Loss: 9.173e-03, Train Accuracy: 1.000
# Epoch: 5, Step: 13500, Train Loss: 9.353e-03, Train Accuracy: 1.000
# Epoch: 5, Step: 13600, Train Loss: 8.831e-02, Train Accuracy: 0.938
# epoch: 5	 train_loss: 1.354e-01	 train_accuracy:0.946	 val_loss: 2.623e-01	 val_accuracy:0.900
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆████████</td></tr><tr><td>final_val_accuracy</td><td>▁</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▅▅▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▄▅▆█</td></tr><tr><td>train_accuracy_step</td><td>▁█▃▁█▃▃▃▆█▆▃▃▆▃█▁▃▃▃▃█▃▆█▆██▆▆█▆███▃▆▆▆█</td></tr><tr><td>train_loss</td><td>█▅▄▃▁</td></tr><tr><td>train_loss_step</td><td>█▂▁▃▃▁▂▂▄▂▁▁▄▃▃▃▃▂▁▂▂▁▃▁▂▁▂▁▃▁▂▁▂▄▃▂▁▂▂▂</td></tr><tr><td>val_accuracy</td><td>▇██▄▁</td></tr><tr><td>val_loss</td><td>▃▁▂▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>5</td></tr><tr><td>final_val_accuracy</td><td>0.8996</td></tr><tr><td>final_val_loss</td><td>0.26233</td></tr><tr><td>global_step</td><td>13600</td></tr><tr><td>train_accuracy</td><td>0.94627</td></tr><tr><td>train_accuracy_step</td><td>0.9375</td></tr><tr><td>train_loss</td><td>0.13542</td></tr><tr><td>train_loss_step</td><td>0.08831</td></tr><tr><td>val_accuracy</td><td>0.8996</td></tr><tr><td>val_loss</td><td>0.26233</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">genial-sponge-46</strong> at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/owku1nn1' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2/runs/owku1nn1</a><br> View project at: <a href='https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2' target="_blank">https://wandb.ai/gmawen-carnegie-mellon-university/clickbait-detection-task2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250325_221805-owku1nn1/logs</code>
# Hyperparameter Tuning Results:
# ------------------------------------------------------------------------------------------------------------------------
# Config     Hidden Size  Layers   Batch Size   Learning Rate  Weight Decay   Optimizer  Val Accuracy
# ------------------------------------------------------------------------------------------------------------------------
# Baseline   128          1        32           0.001          0.0001         Adam       0.9017
# Config 1   256          2        16           0.0005         0.0001         AdamW      0.8969
# Config 2   512          1        64           0.0001         0.0001         SGD        0.8008
# Config 3   64           3        32           0.001          0.0001         Adam       0.9112
# Config 4   128          2        16           0.0001         0.0001         AdamW      0.8960
# Config 5   32           2        16           0.0001         0.0001         Adam       0.8996
# ------------------------------------------------------------------------------------------------------------------------
# Best configuration: Config 3 with validation accuracy: 0.9112

# %% [markdown]
# ## Task 3: Final Evaluation and Error Analysis
#
# In this task, we'll:
# 1. Train the best model configuration from Task 2 on the combined training and validation data
# 2. Evaluate this final model on the test set
# 3. Generate predictions for the provided held-out test set
# 4. Perform detailed error analysis to understand the model's strengths and weaknesses

# %%
# First, train your best model from Task 2
# Replace these parameters with those from your best configuration in Task 2
best_config = {
       "config_name": "Config 2",
        "hidden_size": 256,    # Increased hidden size
        "num_layers": 2,       # Added an extra layer
        "batch_size": 16,      # Reduced batch size
        "optimizer": "AdamW",  # Changed optimizer
        "freeze_base": False,  # Unfreeze base model
        "learning_rate": 5e-4, # Adjusted learning rate
        "weight_decay": 1e-4,  # Do NOT change
        "num_epochs": 5        # Do NOT change
}

# %%
print("\nTraining final model with best configuration...")
final_model = get_model(
    model_name=best_model_name,
    num_classes=2,
    freeze_base=best_config["freeze_base"],
    hidden_size=best_config["hidden_size"],
    num_layers=best_config["num_layers"]
)
# Out:
# Training final model with best configuration...
# Unfroze the last 5 layers out of 22 total layers.

# %%
final_model, _ = train(
    model=final_model,
    train_dataset=dataset['train'],
    val_dataset=dataset['validation'],
    num_epochs=best_config["num_epochs"],
    batch_size=best_config["batch_size"],
    optimizer_cls=best_config["optimizer"],
    lr=best_config["learning_rate"],
    weight_decay=best_config["weight_decay"],
    device=device,
    tokenizer=best_tokenizer,
    use_wandb=False
)
# Out:
# Epoch: 1, Step: 100, Train Loss: 2.230e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 200, Train Loss: 4.124e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 300, Train Loss: 1.058e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 400, Train Loss: 3.652e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 500, Train Loss: 7.551e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 600, Train Loss: 2.432e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 700, Train Loss: 1.513e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 800, Train Loss: 6.277e-01, Train Accuracy: 0.750
# Epoch: 1, Step: 900, Train Loss: 1.559e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1000, Train Loss: 4.063e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1100, Train Loss: 6.766e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 1200, Train Loss: 2.734e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1300, Train Loss: 1.682e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1400, Train Loss: 4.019e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 1500, Train Loss: 1.947e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 1600, Train Loss: 5.020e-02, Train Accuracy: 1.000
# Epoch: 1, Step: 1700, Train Loss: 1.886e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 1800, Train Loss: 1.816e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 1900, Train Loss: 2.186e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2000, Train Loss: 2.702e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2100, Train Loss: 2.482e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2200, Train Loss: 2.099e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2300, Train Loss: 2.279e-01, Train Accuracy: 0.812
# Epoch: 1, Step: 2400, Train Loss: 2.883e-01, Train Accuracy: 0.875
# Epoch: 1, Step: 2500, Train Loss: 1.680e-01, Train Accuracy: 0.938
# Epoch: 1, Step: 2600, Train Loss: 2.010e-01, Train Accuracy: 1.000
# Epoch: 1, Step: 2700, Train Loss: 2.185e-01, Train Accuracy: 0.875
# epoch: 1	 train_loss: 2.458e-01	 train_accuracy:0.908	 val_loss: 2.305e-01	 val_accuracy:0.913
# Epoch: 2, Step: 2800, Train Loss: 6.978e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 2900, Train Loss: 2.122e-01, Train Accuracy: 0.812
# Epoch: 2, Step: 3000, Train Loss: 1.585e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3100, Train Loss: 2.358e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 3200, Train Loss: 8.019e-02, Train Accuracy: 0.938
# Epoch: 2, Step: 3300, Train Loss: 1.969e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3400, Train Loss: 1.561e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3500, Train Loss: 2.733e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 3600, Train Loss: 2.579e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3700, Train Loss: 1.800e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3800, Train Loss: 1.865e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 3900, Train Loss: 2.288e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4000, Train Loss: 6.814e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 4100, Train Loss: 1.349e-01, Train Accuracy: 1.000
# Epoch: 2, Step: 4200, Train Loss: 1.809e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4300, Train Loss: 2.407e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4400, Train Loss: 1.146e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4500, Train Loss: 1.061e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4600, Train Loss: 3.047e-01, Train Accuracy: 0.875
# Epoch: 2, Step: 4700, Train Loss: 1.955e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4800, Train Loss: 2.377e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 4900, Train Loss: 2.117e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5000, Train Loss: 2.976e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5100, Train Loss: 3.090e-01, Train Accuracy: 0.938
# Epoch: 2, Step: 5200, Train Loss: 8.764e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 5300, Train Loss: 7.303e-02, Train Accuracy: 1.000
# Epoch: 2, Step: 5400, Train Loss: 2.935e-01, Train Accuracy: 0.875
# epoch: 2	 train_loss: 2.094e-01	 train_accuracy:0.921	 val_loss: 2.271e-01	 val_accuracy:0.912
# Epoch: 3, Step: 5500, Train Loss: 3.395e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 5600, Train Loss: 1.698e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 5700, Train Loss: 7.528e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 5800, Train Loss: 3.061e-01, Train Accuracy: 0.812
# Epoch: 3, Step: 5900, Train Loss: 3.278e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6000, Train Loss: 2.571e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6100, Train Loss: 2.265e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6200, Train Loss: 5.542e-01, Train Accuracy: 0.750
# Epoch: 3, Step: 6300, Train Loss: 3.276e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6400, Train Loss: 3.194e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6500, Train Loss: 1.245e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 6600, Train Loss: 5.125e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6700, Train Loss: 2.632e-01, Train Accuracy: 0.875
# Epoch: 3, Step: 6800, Train Loss: 9.489e-02, Train Accuracy: 0.938
# Epoch: 3, Step: 6900, Train Loss: 2.156e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7000, Train Loss: 1.385e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7100, Train Loss: 1.503e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7200, Train Loss: 9.819e-02, Train Accuracy: 0.938
# Epoch: 3, Step: 7300, Train Loss: 2.045e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7400, Train Loss: 1.171e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7500, Train Loss: 3.043e-02, Train Accuracy: 1.000
# Epoch: 3, Step: 7600, Train Loss: 3.533e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7700, Train Loss: 1.961e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 7800, Train Loss: 3.999e-01, Train Accuracy: 0.750
# Epoch: 3, Step: 7900, Train Loss: 8.438e-02, Train Accuracy: 0.938
# Epoch: 3, Step: 8000, Train Loss: 2.208e-01, Train Accuracy: 0.938
# Epoch: 3, Step: 8100, Train Loss: 3.924e-01, Train Accuracy: 0.750
# Epoch: 3, Step: 8200, Train Loss: 7.887e-02, Train Accuracy: 1.000
# epoch: 3	 train_loss: 1.918e-01	 train_accuracy:0.925	 val_loss: 2.237e-01	 val_accuracy:0.910
# Epoch: 4, Step: 8300, Train Loss: 9.179e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 8400, Train Loss: 2.692e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 8500, Train Loss: 6.505e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 8600, Train Loss: 1.675e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8700, Train Loss: 7.000e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 8800, Train Loss: 1.622e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 8900, Train Loss: 2.058e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9000, Train Loss: 3.310e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 9100, Train Loss: 2.255e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9200, Train Loss: 1.380e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9300, Train Loss: 3.027e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 9400, Train Loss: 3.592e-01, Train Accuracy: 0.875
# Epoch: 4, Step: 9500, Train Loss: 5.456e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 9600, Train Loss: 2.001e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9700, Train Loss: 2.845e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 9800, Train Loss: 1.250e-01, Train Accuracy: 1.000
# Epoch: 4, Step: 9900, Train Loss: 1.211e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10000, Train Loss: 8.260e-02, Train Accuracy: 0.938
# Epoch: 4, Step: 10100, Train Loss: 9.384e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10200, Train Loss: 1.029e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10300, Train Loss: 2.970e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10400, Train Loss: 8.137e-02, Train Accuracy: 1.000
# Epoch: 4, Step: 10500, Train Loss: 2.822e-01, Train Accuracy: 0.938
# Epoch: 4, Step: 10600, Train Loss: 2.845e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 10700, Train Loss: 7.412e-02, Train Accuracy: 0.938
# Epoch: 4, Step: 10800, Train Loss: 3.846e-01, Train Accuracy: 0.812
# Epoch: 4, Step: 10900, Train Loss: 1.340e-01, Train Accuracy: 0.938
# epoch: 4	 train_loss: 1.784e-01	 train_accuracy:0.931	 val_loss: 2.256e-01	 val_accuracy:0.910
# Epoch: 5, Step: 11000, Train Loss: 1.513e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11100, Train Loss: 6.439e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11200, Train Loss: 1.112e-01, Train Accuracy: 1.000
# Epoch: 5, Step: 11300, Train Loss: 8.186e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11400, Train Loss: 1.234e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11500, Train Loss: 7.296e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 11600, Train Loss: 1.667e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11700, Train Loss: 5.993e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 11800, Train Loss: 1.252e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 11900, Train Loss: 1.174e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12000, Train Loss: 1.594e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 12100, Train Loss: 8.924e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 12200, Train Loss: 3.576e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 12300, Train Loss: 2.991e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 12400, Train Loss: 1.192e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12500, Train Loss: 1.126e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12600, Train Loss: 9.185e-02, Train Accuracy: 0.938
# Epoch: 5, Step: 12700, Train Loss: 1.204e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12800, Train Loss: 1.301e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 12900, Train Loss: 1.602e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13000, Train Loss: 1.655e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13100, Train Loss: 5.716e-02, Train Accuracy: 1.000
# Epoch: 5, Step: 13200, Train Loss: 1.403e-01, Train Accuracy: 0.875
# Epoch: 5, Step: 13300, Train Loss: 2.567e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 13400, Train Loss: 3.750e-01, Train Accuracy: 0.812
# Epoch: 5, Step: 13500, Train Loss: 4.164e-01, Train Accuracy: 0.938
# Epoch: 5, Step: 13600, Train Loss: 4.097e-01, Train Accuracy: 0.875
# epoch: 5	 train_loss: 1.706e-01	 train_accuracy:0.933	 val_loss: 2.387e-01	 val_accuracy:0.902

# %%
print("\nEvaluating final model on test set...")
test_loss, test_acc, test_preds, test_labels, test_logits = evaluate(
    final_model,
    dataset['test'],
    batch_size=32,
    device=device,
    tokenizer=best_tokenizer
)

print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Evaluating final model on test set...
# Test Accuracy: 0.9095
# Test Loss: 0.2308

# %%
# Generate predictions for the held-out test set (test-DIST.json)
test_file_path = 'second-test-data-DIST.json'
if os.path.exists(test_file_path):
    print(f"\nFound test file: {test_file_path}")
    print("Generating predictions for the held-out test set...")

    predict_on_test_set(
        model=final_model,
        tokenizer=best_tokenizer,
        test_file_path=test_file_path,
        output_file_path='test-results.txt',
        device=device
    )

    # Verify the test-results.txt file was created successfully
    if os.path.exists('test-results.txt'):
        with open('test-results.txt', 'r') as f:
            predictions = f.read().strip().split('\n')
        print(f"SUCCESS: Created test-results.txt with {len(predictions)} predictions")
        print(f"Sample predictions (first 5): {predictions[:5] if len(predictions) >= 5 else predictions}")
    else:
        print("ERROR: Failed to create test-results.txt. Please check for errors.")
else:
    print(f"\nERROR: Test file {test_file_path} not found!")
    print("You need this file for your submission. Please make sure it's in your working directory.")
    print("If you're working in Colab, upload the test-DIST.json file to your session.")
# Out:
# Found test file: second-test-data-DIST.json
# Generating predictions for the held-out test set...
# Loaded 882 examples from second-test-data-DIST.json
# Predictions saved to test-results.txt
# SUCCESS: Created test-results.txt with 882 predictions
# Sample predictions (first 5): ['0', '0', '1', '1', '1']

# %% [markdown]
# ## Error Analysis

# %%
# Evaluate on validation set
print("\nEvaluating final model on validation set...")
val_loss, val_acc, val_preds, val_labels, val_logits = evaluate(
    final_model,
    dataset['validation'],
    batch_size=32,
    device=device,
    tokenizer=best_tokenizer
)

# Confusion matrix
val_conf_matrix = confusion_matrix(val_labels, val_preds)
print("\nConfusion Matrix for Validation set:")
print(val_conf_matrix)
print("="*50)
print(f"Validation Accuracy: {val_acc:.4f}")  # Fixed: using val_acc instead of test_acc
print(f"Validation Loss: {val_loss:.4f}")    # Fixed: using val_loss instead of test_loss
print("="*50)
print(f"False Positives (Real to Fake): {val_conf_matrix[0][1]}")
print(f"False Negatives (Fake to Real): {val_conf_matrix[1][0]}")
print("="*50)

# Get validation texts
val_texts = [item['text'] for item in dataset['validation']]

# Analyze misclassified examples
misclassified_indices = [i for i, (pred, label) in enumerate(zip(val_preds, val_labels)) if pred != label]

if misclassified_indices:
    print("\nAnalyzing misclassified examples...")
    print(f"Total misclassified: {len(misclassified_indices)}")

    # Print first 5 examples of each error type
    false_positives = [i for i in misclassified_indices if val_preds[i] == 1]
    false_negatives = [i for i in misclassified_indices if val_preds[i] == 0]

    if false_positives:
        print("\nFalse Positives (Real news predicted as Fake):")
        for i in false_positives[:5]:
            print(f"\nExample {i}:")
            print(f"Text: {val_texts[i]}")
            print(f"True Label: Real")
            print(f"Predicted Label: Fake")

    if false_negatives:
        print("\nFalse Negatives (Fake news predicted as Real):")
        for i in false_negatives[:5]:
            print(f"\nExample {i}:")
            print(f"Text: {val_texts[i]}")
            print(f"True Label: Fake")
            print(f"Predicted Label: Real")
else:
    print("\nNo misclassified examples found!")
# Out:
# Evaluating final model on validation set...
#
# Confusion Matrix for Validation set:
# [[1310   68]
#  [ 147  666]]
# ==================================================
# Validation Accuracy: 0.9016
# Validation Loss: 0.2381
# ==================================================
# False Positives (Real to Fake): 68
# False Negatives (Fake to Real): 147
# ==================================================
#
# Analyzing misclassified examples...
# Total misclassified: 215
#
# False Positives (Real news predicted as Fake):
#
# Example 49:
# Text: The Totally, Very Much Unedited Video Of Trump's Truck Photo Op
# True Label: Real
# Predicted Label: Fake
#
# Example 99:
# Text: Kim Kardashian's fashion icon may just be one of your favorite characters from 'The Office'
# True Label: Real
# Predicted Label: Fake
#
# Example 123:
# Text: Here Are The 2017 Grammy Nominations
# True Label: Real
# Predicted Label: Fake
#
# Example 191:
# Text: 5 Andra Day Songs You Should Know
# True Label: Real
# Predicted Label: Fake
#
# Example 207:
# Text: Why Jay Z's New Venture Fund Should Come As No Surprise
# True Label: Real
# Predicted Label: Fake
#
# False Negatives (Fake news predicted as Real):
#
# Example 18:
# Text: Survey Points to Challenges NATO Faces Over Russia
# True Label: Fake
# Predicted Label: Real
#
# Example 101:
# Text: YouTube Meets Boob Tube as Europe’s Networks Chase the Young
# True Label: Fake
# Predicted Label: Real
#
# Example 102:
# Text: Whole Foods Wanted to Be More Than a Supermarket, and Therein Lies the Problem
# True Label: Fake
# Predicted Label: Real
#
# Example 106:
# Text: Gay in Putin's Moscow: why the city is pinker than you think
# True Label: Fake
# Predicted Label: Real
#
# Example 113:
# Text: Night Owls Become Early Risers
# True Label: Fake
# Predicted Label: Real

# %% [markdown]
# ## Submission Instructions
#
# When you're ready to submit your assignment, please follow these steps:
#
# 1. Submit this completed ipynb **without clearing any output cells**, renamed as `hw3.ipynb`
#    - Make sure your code can load the best model configuration
#    - Include necessary functions for tokenization, prediction, etc.
#    - Make sure it can run the test predictions on `test-DIST.json`
#
# 2. Download `test-results.txt` this notebook generated with your predictions on the provided test set. Perform a manual check to see if:
#    - Each line should contain a single character: '1' for clickbait or '0' for non-clickbait
#    - No other content should be in this file
#
# 3. Read and complete the hw3 report (report.pdf). It has the following sections:
#    - Part 1: Model Selection
#      - Compare BERT vs ModernBERT performance
#      - Explain your choice of model and why it performed better
#      - Discuss any observations about tokenization differences
#
#    - Part 2: Hyperparameter Tuning
#      - Table with all configurations tested and their results
#      - Analysis of how different hyperparameters affected performance
#      - Include and explain wandb plots
#      - Justify your final model configuration
#
# Submit the following files to Gradescope:
# - `hw3.ipynb`: Your code implementation
# - `test-results.txt`: Predictions on the test set
# - `report.pdf`: Your detailed report
#
# Make sure your name and Andrew ID are on the first page of your report.
